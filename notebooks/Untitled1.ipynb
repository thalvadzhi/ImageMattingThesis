# %%
import keras
from keras.models import Model, Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, ZeroPadding2D, BatchNormalization, UpSampling2D,Reshape,Concatenate, Lambda
import numpy as np
import keras.backend as K

# %%
from keras import backend as K
from keras.engine.topology import Layer
from keras.layers import Lambda, Multiply


class Unpooling(Layer):

    def __init__(self, **kwargs):
        super(Unpooling, self).__init__(**kwargs)

    def build(self, input_shape):
        super(Unpooling, self).build(input_shape)

    def call(self, inputs, **kwargs):
        x = inputs[:, 1]
#         print('x.shape: ' + str(K.int_shape(x)))
        bool_mask = Lambda(lambda t: K.greater_equal(t[:, 0], t[:, 1]),
                           output_shape=K.int_shape(x)[1:])(inputs)
        # print('bool_mask.shape: ' + str(K.int_shape(bool_mask)))
        mask = Lambda(lambda t: K.cast(t, dtype='float32'))(bool_mask)
        # print('mask.shape: ' + str(K.int_shape(mask)))
        x = Multiply()([mask, x])
        # print('x.shape: ' + str(K.int_shape(x)))
        return x

    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[2], input_shape[3], input_shape[4]

# %%
def build_encoder_decoder():
    # Encoder
    input_tensor = Input(shape=(320, 320, 4))
    x = ZeroPadding2D((1, 1))(input_tensor)
    x = Conv2D(64, (3, 3), activation='relu', name='conv1_1')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(64, (3, 3), activation='relu', name='conv1_2')(x)
    orig_1 = x
    x = MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(128, (3, 3), activation='relu', name='conv2_1')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(128, (3, 3), activation='relu', name='conv2_2')(x)
    orig_2 = x
    x = MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(256, (3, 3), activation='relu', name='conv3_1')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(256, (3, 3), activation='relu', name='conv3_2')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(256, (3, 3), activation='relu', name='conv3_3')(x)
    orig_3 = x
    x = MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(512, (3, 3), activation='relu', name='conv4_1')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(512, (3, 3), activation='relu', name='conv4_2')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(512, (3, 3), activation='relu', name='conv4_3')(x)
    orig_4 = x
    x = MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(512, (3, 3), activation='relu', name='conv5_1')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(512, (3, 3), activation='relu', name='conv5_2')(x)
    x = ZeroPadding2D((1, 1))(x)
    x = Conv2D(512, (3, 3), activation='relu', name='conv5_3')(x)
    orig_5 = x
    x = MaxPooling2D((2, 2), strides=(2, 2))(x)

    # Decoder
    # x = Conv2D(4096, (7, 7), activation='relu', padding='valid', name='conv6')(x)
    # x = BatchNormalization()(x)
    # x = UpSampling2D(size=(7, 7))(x)

    x = Conv2D(512, (1, 1), activation='relu', padding='same', name='deconv6', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D(size=(2, 2))(x)
    the_shape = K.int_shape(orig_5)
    shape = (1, the_shape[1], the_shape[2], the_shape[3])
    origReshaped = Reshape(shape)(orig_5)
    print("Orig5 shape: {} ; Orig5reshaped: {}".format(K.int_shape(orig_5), K.int_shape(origReshaped)))

    # print('origReshaped.shape: ' + str(K.int_shape(origReshaped)))
    xReshaped = Reshape(shape)(x)
    print("X shape: {} ; X reshaped: {}".format(K.int_shape(x), K.int_shape(xReshaped)))

    # print('xReshaped.shape: ' + str(K.int_shape(xReshaped)))
    together = Concatenate(axis=1)([origReshaped, xReshaped])
    print('together.shape: ' + str(K.int_shape(together)))
    x = Unpooling()(together)

    x = Conv2D(512, (5, 5), activation='relu', padding='same', name='deconv5', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D(size=(2, 2))(x)
    the_shape = K.int_shape(orig_4)
    shape = (1, the_shape[1], the_shape[2], the_shape[3])
    origReshaped = Reshape(shape)(orig_4)
    xReshaped = Reshape(shape)(x)
    together = Concatenate(axis=1)([origReshaped, xReshaped])
    x = Unpooling()(together)

    x = Conv2D(256, (5, 5), activation='relu', padding='same', name='deconv4', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D(size=(2, 2))(x)
    the_shape = K.int_shape(orig_3)
    shape = (1, the_shape[1], the_shape[2], the_shape[3])
    origReshaped = Reshape(shape)(orig_3)
    xReshaped = Reshape(shape)(x)
    together = Concatenate(axis=1)([origReshaped, xReshaped])
    x = Unpooling()(together)

    x = Conv2D(128, (5, 5), activation='relu', padding='same', name='deconv3', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D(size=(2, 2))(x)
    the_shape = K.int_shape(orig_2)
    shape = (1, the_shape[1], the_shape[2], the_shape[3])
    origReshaped = Reshape(shape)(orig_2)
    xReshaped = Reshape(shape)(x)
    together = Concatenate(axis=1)([origReshaped, xReshaped])
    x = Unpooling()(together)

    x = Conv2D(64, (5, 5), activation='relu', padding='same', name='deconv2', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)
    x = BatchNormalization()(x)
    x = UpSampling2D(size=(2, 2))(x)
    the_shape = K.int_shape(orig_1)
    shape = (1, the_shape[1], the_shape[2], the_shape[3])
    origReshaped = Reshape(shape)(orig_1)
    xReshaped = Reshape(shape)(x)
    together = Concatenate(axis=1)([origReshaped, xReshaped])
    x = Unpooling()(together)
    x = Conv2D(64, (5, 5), activation='relu', padding='same', name='deconv1', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)
    x = BatchNormalization()(x)

    x = Conv2D(1, (5, 5), activation='sigmoid', padding='same', name='pred', kernel_initializer='he_normal',
               bias_initializer='zeros')(x)

    model = Model(inputs=input_tensor, outputs=x)
    return model

# %%
model = build_encoder_decoder()
# Out:
# Orig5 shape: (None, 20, 20, 512) ; Orig5reshaped: (None, 1, 20, 20, 512)
# X shape: (None, 20, 20, 512) ; X reshaped: (None, 1, 20, 20, 512)
# together.shape: (None, 2, 20, 20, 512)
# x.shape: (None, 20, 20, 512)
# x.shape: (None, 40, 40, 512)
# x.shape: (None, 80, 80, 256)
# x.shape: (None, 160, 160, 128)
# x.shape: (None, 320, 320, 64)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_18 (InputLayer)           (None, 320, 320, 4)  0
# __________________________________________________________________________________________________
# zero_padding2d_209 (ZeroPadding (None, 322, 322, 4)  0           input_18[0][0]
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 320, 320, 64) 2368        zero_padding2d_209[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_210 (ZeroPadding (None, 322, 322, 64) 0           conv1_1[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 320, 320, 64) 36928       zero_padding2d_210[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_81 (MaxPooling2D) (None, 160, 160, 64) 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_211 (ZeroPadding (None, 162, 162, 64) 0           max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 160, 160, 128 73856       zero_padding2d_211[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_212 (ZeroPadding (None, 162, 162, 128 0           conv2_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 160, 160, 128 147584      zero_padding2d_212[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_82 (MaxPooling2D) (None, 80, 80, 128)  0           conv2_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_213 (ZeroPadding (None, 82, 82, 128)  0           max_pooling2d_82[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 80, 80, 256)  295168      zero_padding2d_213[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_214 (ZeroPadding (None, 82, 82, 256)  0           conv3_1[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 80, 80, 256)  590080      zero_padding2d_214[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_215 (ZeroPadding (None, 82, 82, 256)  0           conv3_2[0][0]
# __________________________________________________________________________________________________
# conv3_3 (Conv2D)                (None, 80, 80, 256)  590080      zero_padding2d_215[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_83 (MaxPooling2D) (None, 40, 40, 256)  0           conv3_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_216 (ZeroPadding (None, 42, 42, 256)  0           max_pooling2d_83[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 40, 40, 512)  1180160     zero_padding2d_216[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_217 (ZeroPadding (None, 42, 42, 512)  0           conv4_1[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 40, 40, 512)  2359808     zero_padding2d_217[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_218 (ZeroPadding (None, 42, 42, 512)  0           conv4_2[0][0]
# __________________________________________________________________________________________________
# conv4_3 (Conv2D)                (None, 40, 40, 512)  2359808     zero_padding2d_218[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_84 (MaxPooling2D) (None, 20, 20, 512)  0           conv4_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_219 (ZeroPadding (None, 22, 22, 512)  0           max_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 20, 20, 512)  2359808     zero_padding2d_219[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_220 (ZeroPadding (None, 22, 22, 512)  0           conv5_1[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 20, 20, 512)  2359808     zero_padding2d_220[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_221 (ZeroPadding (None, 22, 22, 512)  0           conv5_2[0][0]
# __________________________________________________________________________________________________
# conv5_3 (Conv2D)                (None, 20, 20, 512)  2359808     zero_padding2d_221[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_85 (MaxPooling2D) (None, 10, 10, 512)  0           conv5_3[0][0]
# __________________________________________________________________________________________________
# deconv6 (Conv2D)                (None, 10, 10, 512)  262656      max_pooling2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 10, 10, 512)  2048        deconv6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_35 (UpSampling2D) (None, 20, 20, 512)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# reshape_65 (Reshape)            (None, 1, 20, 20, 51 0           conv5_3[0][0]
# __________________________________________________________________________________________________
# reshape_66 (Reshape)            (None, 1, 20, 20, 51 0           up_sampling2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 2, 20, 20, 51 0           reshape_65[0][0]
#                                                                  reshape_66[0][0]
# __________________________________________________________________________________________________
# unpooling_31 (Unpooling)        (None, 20, 20, 512)  0           concatenate_32[0][0]
# __________________________________________________________________________________________________
# deconv5 (Conv2D)                (None, 20, 20, 512)  6554112     unpooling_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 20, 20, 512)  2048        deconv5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_36 (UpSampling2D) (None, 40, 40, 512)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# reshape_67 (Reshape)            (None, 1, 40, 40, 51 0           conv4_3[0][0]
# __________________________________________________________________________________________________
# reshape_68 (Reshape)            (None, 1, 40, 40, 51 0           up_sampling2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 2, 40, 40, 51 0           reshape_67[0][0]
#                                                                  reshape_68[0][0]
# __________________________________________________________________________________________________
# unpooling_32 (Unpooling)        (None, 40, 40, 512)  0           concatenate_33[0][0]
# __________________________________________________________________________________________________
# deconv4 (Conv2D)                (None, 40, 40, 256)  3277056     unpooling_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 40, 40, 256)  1024        deconv4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_37 (UpSampling2D) (None, 80, 80, 256)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# reshape_69 (Reshape)            (None, 1, 80, 80, 25 0           conv3_3[0][0]
# __________________________________________________________________________________________________
# reshape_70 (Reshape)            (None, 1, 80, 80, 25 0           up_sampling2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 2, 80, 80, 25 0           reshape_69[0][0]
#                                                                  reshape_70[0][0]
# __________________________________________________________________________________________________
# unpooling_33 (Unpooling)        (None, 80, 80, 256)  0           concatenate_34[0][0]
# __________________________________________________________________________________________________
# deconv3 (Conv2D)                (None, 80, 80, 128)  819328      unpooling_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 80, 80, 128)  512         deconv3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_38 (UpSampling2D) (None, 160, 160, 128 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# reshape_71 (Reshape)            (None, 1, 160, 160,  0           conv2_2[0][0]
# __________________________________________________________________________________________________
# reshape_72 (Reshape)            (None, 1, 160, 160,  0           up_sampling2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 2, 160, 160,  0           reshape_71[0][0]
#                                                                  reshape_72[0][0]
# __________________________________________________________________________________________________
# unpooling_34 (Unpooling)        (None, 160, 160, 128 0           concatenate_35[0][0]
# __________________________________________________________________________________________________
# deconv2 (Conv2D)                (None, 160, 160, 64) 204864      unpooling_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 160, 160, 64) 256         deconv2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_39 (UpSampling2D) (None, 320, 320, 64) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# reshape_73 (Reshape)            (None, 1, 320, 320,  0           conv1_2[0][0]
# __________________________________________________________________________________________________
# reshape_74 (Reshape)            (None, 1, 320, 320,  0           up_sampling2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 2, 320, 320,  0           reshape_73[0][0]
#                                                                  reshape_74[0][0]
# __________________________________________________________________________________________________
# unpooling_35 (Unpooling)        (None, 320, 320, 64) 0           concatenate_36[0][0]
# __________________________________________________________________________________________________
# deconv1 (Conv2D)                (None, 320, 320, 64) 102464      unpooling_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 320, 320, 64) 256         deconv1[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 320, 320, 1)  1601        batch_normalization_46[0][0]
# ==================================================================================================
# Total params: 25,943,489
# Trainable params: 25,940,417
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
